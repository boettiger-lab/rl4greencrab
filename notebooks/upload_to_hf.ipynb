# %%
from rl4greencrab.utils.hugging_face import upload_folder_to_hf

# %%
# upload data folder
upload_folder_to_hf(
    folder_path="../data/rl_policies",
    path_in_repo="rl4greencrab/data/rl_policies",
    repo="boettiger-lab/rl4eco"
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %%
# upload model folder
upload_folder_to_hf(
    folder_path="../saved_agents",
    path_in_repo="rl4greencrab/saved_agents",
    repo="boettiger-lab/rl4eco",
    ignore_patterns=["archive/*"]
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
